# %%
import requests

# %%
# url = "https://mypersonalcloudmaqsyplo-myimagegen2.functions.fnc.fr-par.scw.cloud"
url = "http://localhost:8080"
my_prompt = "The picture of Frankfurt Bahnhofsviertel at night. It should be done in comic style."

response = requests.get(url, params={"prompt": my_prompt})

# %%
response
# Out:
# <Response [500]>

# %%
from IPython import display
from base64 import b64decode

display.Image(b64decode(response.json()['b64_image']))
