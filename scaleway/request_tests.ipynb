# %%
import requests

# %%
# url = "https://mypersonalcloudmaqsyplo-ionosimagegen.functions.fnc.fr-par.scw.cloud"
url = "http://localhost:8080"
my_prompt = "The picture of Frankfurt Rödelheim in the morning. It should be done in comic style."

response = requests.get(url, params={"prompt": my_prompt})

# %%
response
# Out:
# <Response [200]>

# %%
#  download the image from the response url

image_url = response.json()["image_path"]
image_response = requests.get(image_url)

# %%
image_response.json()
# Out:
# {'body': {'b64_image': '...'}}

# %%
from IPython import display
from base64 import b64decode

display.Image(b64decode(image_response.json()["body"]['b64_image']))
